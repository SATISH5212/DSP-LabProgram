# %%
import folium
world_map = folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
nuzvid=folium.Map(location=[16.7850, 80.8488])
nuzvid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from branca.element import Figure
fig=Figure(width=1000,height=350)
map1=folium.Map(location=[16.7850, 80.8488])
coord1=[[16.7850, 80.8488],[16.776849524165826, 80.86840930309428],[16.700573610658616, 80.93432726731125],[16.699258248340314, 81.02084462244969],
                          [16.738715392087467, 81.07028309561241],[16.74397572763573, 81.09500233219379],[16.74660584092759, 81.16366687825312],
                          [16.906973864641202, 81.35318102537693],[16.964778124428097, 81.4081126622244],[16.977912977808664, 81.471284044599],
                          [17.056702776328507, 81.58114737495661],[17.033069320968814, 81.69375723049393],[17.046199387377875, 81.80362050418887],
                          [17.09345998359364, 81.91897694156857],[17.161704123210665, 82.0425731244754],[17.237792979577833, 82.16067614369747],
                          [17.224676443706258, 82.24032701712629],[17.326960691105416, 82.47653303781624],[17.371528329124512, 82.57266340229933],
                          [17.400360436444082, 82.64956769388579],[17.43442888342649, 82.753937803896],[17.50778545983201, 82.80886944074348],[17.588967120671132, 82.87753398680282],
                          [17.657026867746833, 82.92971904180793],[17.69497209420402, 82.9942637233676],[17.749913038591032, 83.0794077604812],[17.800914528105967, 83.16043187765884],
                          [17.86627973997438, 83.29226780609277],[17.88719153659515, 83.34994602478262],[17.957750651616966, 83.42685031636908],[18.007386492632648, 83.4790353713742],
                          [18.075286571410192, 83.53671359006404],[18.130109781897147, 83.58065889954203],[18.17969693973276, 83.67129610034037],[18.208398856778572, 83.69601533692172],
                          [18.239704645600526, 83.74545381008446],[18.263180289042666, 83.79489228324718],[18.323159172706323, 83.8031320287743]]

coord2=[[16.788712177733093, 80.84514152804819],[16.72950151473812, 80.99692365592392],[16.788712177733093, 81.22178606759165],[16.95010183440059, 81.37356819546739],[17.009243417968058, 81.4522700395511],
        [17.052243756165183, 81.59280904684344],[17.04149459854085, 81.70524025267731],[17.064579925851515, 81.87228499358555],[17.09083470452031, 81.97116193991098],[17.056702771784565, 82.1606760870348],
        [16.967405168614786, 82.22659405125175],[17.072456747500407, 82.25680645151787],[17.216806070732, 82.31173808836535],[17.253531588313205, 82.36666972521283],[17.298117031398462, 82.42984110758742],
        [17.342691672147186, 82.48477274443489],[17.384634385514286, 82.5781565270756],[17.3977395134486, 82.65780740050444],[17.44753042916378, 82.76217751051466],[17.523500866870318, 82.81985572920448],
        [17.612529159582458, 82.88028052973671],[17.675346244052434, 83.00387671264355],[17.727677058324648, 83.102753658969],[17.828370838875777, 83.22634984187583],[17.917247928508548, 83.41174411623605],
        [18.17969693973276, 83.67129610034037],[18.208398856778572, 83.69601533692172],[18.239704645600526, 83.74545381008446],[18.263180289042666, 83.79489228324718],[18.323159172706323, 83.8031320287743]]
f1=folium.FeatureGroup("path 1")
f2=folium.FeatureGroup("path 2")

line_1=folium.vector_layers.PolyLine(coord1,popup='<b>Path </b>',tooltip='path1',color='blue',weight=5).add_to(f1)
line_2=folium.vector_layers.PolyLine(coord2,popup='<b>Path2</b>',tooltip='path2',color='red',weight=7).add_to(f2)

folium.Marker(location=[17.772509929247573, 83.11436959603873],tooltip='dfvbnm,',icon=folium.Icon(color='purple',prefix='fa',icon='fa-cutlery')).add_to(map1)
folium.Marker(location=[17.356094747477577, 82.54134748410122],tooltip='<strong>hhhh</strong>',icon=folium.Icon(color='green',prefix='fa',icon='fa-h-square')).add_to(map1)
folium.Marker(location=[18.14940336948086, 83.63130380107341],popup='<h3 style="color:green;">restaurent</h3>',tooltip='<strong></strong>',icon=folium.Icon(color='purple',prefix='fa',icon='fa-cutlery')).add_to(map1)
folium.Marker(location=[17.90135478563519, 83.3938544011032],popup='<h3 style="color:green;"></h3>',tooltip='<strong></strong>',icon=folium.Icon(color='purple',prefix='fa',icon='fa-cutlery')).add_to(map1)
folium.Marker(location=[18.257852437196934, 83.7835288284158],popup='<h3 style="color:green;">temple</h3>',tooltip='<strong></strong>',icon=folium.Icon(color='red',prefix='fa',icon='fa-bell')).add_to(map1)
folium.Marker(location=[16.967764464904416, 82.23395840185015],popup='<h3 style="color:green;">railway station</h3>',tooltip='<strong></strong>',icon=folium.Icon(color='blue',prefix='fa',icon='fa-subway')).add_to(map1)
folium.Marker(location=[16.807168693122513, 80.84360340719091],popup='<h3 style="color:green;"></h3>',tooltip='<strong></strong>',icon=folium.Icon(color='yellow',prefix='fa',icon='fa-cutlery')).add_to(map1)
folium.Marker(location=[17.00795549742573, 81.72740280140034],popup='<h3 style="color:green;"></h3>',tooltip='<strong></strong>',icon=folium.Icon(color='blue',prefix='fa',icon='fa-subway')).add_to(map1)
folium.Marker(location=[16.982004254302748, 82.23970422030247],popup='<h3 style="color:green;"></h3>',tooltip='<strong></strong>',icon=folium.Icon(color='purple',prefix='fa',icon='university')).add_to(map1)
folium.Marker(location=[16.706797539701466, 81.09076411417148],popup='<h3 style="color:green;">nri collage</h3>',tooltip='<strong>collage</strong>',icon=folium.Icon(color='lightgrey',prefix='fa',icon='university')).add_to(map1)
folium.Marker(location=[17.570025250616613, 82.86255649368623],popup='<h3 style="color:green;">bus stop</h3>',tooltip='<strong>bus</strong>',icon=folium.Icon(color='yellow',prefix='fa',icon='bus')).add_to(map1)
f1.add_to(map1)
f2.add_to(map1)
map1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: UserWarning: color argument of Icon should be one of: {'lightgray', 'pink', 'lightred', 'white', 'lightgreen', 'purple', 'red', 'darkgreen', 'lightblue', 'gray', 'darkpurple', 'blue', 'black', 'darkred', 'darkblue', 'cadetblue', 'green', 'orange', 'beige'}.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:38: UserWarning: color argument of Icon should be one of: {'lightgray', 'pink', 'lightred', 'white', 'lightgreen', 'purple', 'red', 'darkgreen', 'lightblue', 'gray', 'darkpurple', 'blue', 'black', 'darkred', 'darkblue', 'cadetblue', 'green', 'orange', 'beige'}.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:39: UserWarning: color argument of Icon should be one of: {'lightgray', 'pink', 'lightred', 'white', 'lightgreen', 'purple', 'red', 'darkgreen', 'lightblue', 'gray', 'darkpurple', 'blue', 'black', 'darkred', 'darkblue', 'cadetblue', 'green', 'orange', 'beige'}.
# ...
